# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head(8)
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
# 5       CONFIRMED              0              0              0              0
# 6       CONFIRMED              0              0              0              0
# 7       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
# 5    2.566589     1.780000e-05    -1.780000e-05   179.554370
# 6   16.068647     1.090000e-05    -1.090000e-05   173.621937
# 7    2.470613     2.700000e-08    -2.700000e-08   122.763305
#
#    koi_time0bk_err1     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520     ...                 -81      4.467           0.064
# 1          0.000581     ...                -176      4.544           0.044
# 2          0.000115     ...                -174      4.564           0.053
# 3          0.001130     ...                -211      4.438           0.070
# 4          0.001900     ...                -232      4.486           0.054
# 5          0.004610     ...                -232      4.486           0.054
# 6          0.000517     ...                 -83      4.485           0.083
# 7          0.000009     ...                 -78      4.457           0.024
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
# 5          -0.229     0.972          0.315         -0.105  296.28613
# 6          -0.028     0.848          0.033         -0.072  286.99948
# 7          -0.024     0.964          0.038         -0.038  286.80847
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
# 5  48.224670      15.714
# 6  48.375790      15.841
# 7  49.316399      11.338
#
# [8 rows x 41 columns]

# %%
df.shape
# Out:
# (6991, 41)

# %%
from sklearn.datasets import make_regression
# Make batch model
X, y = make_regression(n_samples=6991, n_features=1, random_state=0, noise=4, bias=100.0)

# %%
plt.scatter(X, y)

# %%
print('Weight coefficients: ', model.coef_)  # array
print('y-axis intercept: ', model.intercept_)  # one number
# Out:
# Weight coefficients:  [79.77667447]
# y-axis intercept:  100.07474562153847

# %% [markdown]
# # Our linear model now looks like this:
#
# $y =  100.07474562153847 + 79.77667447 x$

# %%
df.describe()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2     ...       koi_steff_err2  \
# count       6991.000000       6991.000000     ...          6991.000000
# mean           0.009340         -0.009340     ...          -161.206980
# std            0.021989          0.021989     ...            71.448481
# min            0.000009         -0.569000     ...         -1733.000000
# 25%            0.001145         -0.010000     ...          -197.000000
# 50%            0.003990         -0.003990     ...          -159.000000
# 75%            0.010000         -0.001145     ...          -112.000000
# max            0.569000         -0.000009     ...             0.000000
#
#          koi_slogg  koi_slogg_err1  koi_slogg_err2     koi_srad  \
# count  6991.000000     6991.000000      6991.00000  6991.000000
# mean      4.305049        0.121091        -0.14048     1.740749
# std       0.439238        0.132048         0.08199     5.903415
# min       0.047000        0.000000        -1.00700     0.109000
# 25%       4.209000        0.044000        -0.19500     0.829000
# 50%       4.436000        0.070000        -0.12700     0.999000
# 75%       4.543000        0.149000        -0.08800     1.357000
# max       5.364000        1.472000         0.00000   180.013000
#
#        koi_srad_err1  koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000    6991.000000  6991.000000  6991.000000  6991.000000
# mean        0.352710      -0.388568   292.082406    43.812143    14.271508
# std         0.839017       1.907797     4.762908     3.606167     1.350802
# min         0.000000    -103.825000   279.856080    36.577381     6.966000
# 25%         0.128000      -0.252000   288.704730    40.797760    13.455000
# 50%         0.248000      -0.111000   292.314760    43.679661    14.534000
# 75%         0.357000      -0.069000   295.888550    46.693659    15.322000
# max        25.956000       0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 40 columns]

# %% [markdown]
# # Select your features (columns)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.fit(X, y) # x,y are labels
print(model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_steff_err2', 'koi_time0bk', 'ra', 'koi_slogg', 'koi_slogg']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['koi_disposition']
X = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
       'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
       'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
       'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
       'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
       'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
       'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
       'koi_kepmag']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4002              0              0              1              0   99.673478
# 4246              0              1              0              0    0.592244
# 548               0              1              1              0    9.991625
# 3953              0              1              0              0  178.412990
# 2362              0              0              0              0   45.294223
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4002     3.463000e-04    -3.463000e-04   219.334830          0.002300
# 4246     9.000000e-08    -9.000000e-08   131.654831          0.000124
# 548      5.360000e-06    -5.360000e-06   137.447816          0.000445
# 3953     3.100000e-05    -3.100000e-05   218.225235          0.000127
# 2362     5.600000e-05    -5.600000e-05   138.678725          0.000987
#
#       koi_time0bk_err2     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4002         -0.002300     ...                -148      4.777           0.040
# 4246         -0.000124     ...                -146      4.664           0.056
# 548          -0.000445     ...                -176      4.338           0.153
# 3953         -0.000127     ...                -134      4.346           0.084
# 2362         -0.000987     ...                 -68      4.347           0.030
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4002          -0.027     0.492          0.026         -0.027  293.05801
# 4246          -0.032     0.591          0.045         -0.045  290.28094
# 548           -0.187     1.096          0.309         -0.206  301.04239
# 3953          -0.126     1.148          0.202         -0.124  288.32785
# 2362          -0.030     1.044          0.057         -0.042  285.67938
#
#             dec  koi_kepmag
# 4002  45.248821      15.801
# 4246  45.464260      15.653
# 548   45.022888      14.039
# 3953  38.627621      13.944
# 2362  50.241299      10.961
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Scale your data
X_scale = MinMaxScaler().fit(X_train)

# %%
scaled_X_train = X_scale.transform(X_train)
scaled_X_test = X_scale.transform(X_test)

# %%
# Sample testing
scaled_X_test
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.28776822, 0.43048361,
#         0.68422794],
#        [0.        , 1.        , 0.        , ..., 0.41299072, 0.53283969,
#         0.64452899],
#        [0.        , 1.        , 0.        , ..., 0.55094746, 0.51506547,
#         0.68464147],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.79575644, 0.24898041,
#         0.4616657 ],
#        [0.        , 0.        , 0.        , ..., 0.46195188, 0.66541511,
#         0.64825077],
#        [0.        , 1.        , 0.        , ..., 0.35581495, 0.4305845 ,
#         0.73120503]])

# %% [markdown]
# ## Create the Model (Logistic Regression) for Classification

# %%
# import the logistic regression from sklearn

# %% [markdown]
# # Train the Model

# %%
print(f"Training Data Score: {model2.score(scaled_X_train, y_train)}")
print(f"Testing Data Score: {model2.score(scaled_X_test, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7edc0635ac5f> in <module>
# ----> 1 print(f"Training Data Score: {model2.score(scaled_X_train, y_train)}")
#       2 print(f"Testing Data Score: {model2.score(scaled_X_test, y_test)}")
#
# NameError: name 'model2' is not defined

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
